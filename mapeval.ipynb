# %%
from datasets import load_dataset, Dataset

data = load_dataset("MapEval/MapEval-Textual")["test"]
print(data)

def get_question(x):
    question = x["question"]
    print(question)

questions = data.map(get_question)
# Out:
# Dataset({
#     features: ['id', 'context', 'question', 'options', 'answer', 'classification'],
#     num_rows: 300
# })
# Map:   0%|          | 0/300 [00:00<?, ? examples/s]
# I am currently staying at Hostel El Grial in Cusco, Peru. I want to visit Sacsayhuamán for 1.5 hours, Qorikancha Temple for 1 hour, the Cusco Cathedral for 1.5 hours, and the Mercado Central de San Pedro for 1 hour. I have 6 hours available. I will leave my hostel at 8 am. Give the most optimized order to visit these places. I will drive my car.
# I am driving to Brassica in Bexley Via E Whittier St. After reaching Alum Creek Dr, where should I go next?
# I'm at Khansa Market and feeling really hungry. Where can I get something to eat quickly?
# Which pair of places is farthest from each other in Greece?
# ...
